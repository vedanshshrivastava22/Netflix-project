# %% [markdown]
# # Data Cleaning Using Python

# %% [markdown]
# ## Overview

# %% [markdown]
# Netflix is one of the most popular media and video streaming platforms. They have over 8000 movies or tv shows available on their platform, as of mid-2021, they have over 200M Subscribers globally. This tabular dataset consists of listings of all the movies and tv shows available on Netflix, along with details such as - cast, directors, ratings, release year, duration, etc.

# %% [markdown]
# The main aim of this python script is to clean the data using Python libraries and then visualize it for useful insights using Tableau

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Getting an overview of data for dealing with duplicate and null values

# %%
# importing required libraries
import pandas as pd
import numpy as np

# %%
# reading in the data into a pandas dataframe
data = pd.read_csv('netflix_titles.csv')

# %%
# a broad summary of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# As per above information, there are some columns with null values, which will be dealt with later in the code

# %%
# examining a few rows of the dataframe
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# show_id is an id for every record in the dataset, so it should be unique.
# The following code checks for duplicate enteries in this column

# %%
# checking duplicate records in show_id column
sum(data.duplicated(subset='show_id',keep=False))
# Out:
# 0

# %% [markdown]
# There are no duplicate values in the column, suggesting no problem with data validation so far.
# Similar process is repeated below for title column, because no two movies or TV shows shall have the same name. There are no duplicates in this column as well

# %%
sum(data.duplicated(subset='title',keep=False)) # no duplicates for title column, and it should be
# Out:
# 0

# %%
# checking for number of null values in every column
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# The number of null values in director, cast and country column are not negliegible as compared to the number of records in the datasets, making it impossible to directly drop the rows containing null values for these columns. Thus, the null values are treated accordingly in the below sections of code

# %% [markdown]
# ### Cleaning null values in director column

# %% [markdown]
# Filling null values in director name is something that cannot be achieved by a mathematical logic. Like replacing null values with min,max,mean etc of a numerical column.

# %% [markdown]
# One of the ways to deal with null director names is to explore relationship between cast and director.
# One can reasonably assume that if exactly same director,cast pair appears 3 or more times in the dataset, then in cases where director is null but the cast column is not null and contains the same cast as that in the pair, then it can be assumed that the director in that case is also the one in the pair

# %% [markdown]
# So, in the below code, the director and cast columns are combined and then their repetition frequency is analyzed to further clean null values in the director column.

# %%
# combining director and cast columns into dcast column, with --- between the two column values for clear separation
data['dcast'] = data['director'] + '---' + data['cast']

# %% [markdown]
# Below, the values in the dcast column which appear more than 3 times in the dataset are stored in variable found directors. As these are the directors we will be able to replace if they are null but have the cast column as non-null and hold same value as given after ---

# %%
# storing the relevant values in variable found_directors
found_directors = list(data['dcast'].value_counts()[data['dcast'].value_counts()>=3].index)

# %%
found_directors
# Out:
# ['Rajiv Chilaka---Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil',
#  'Rathindran R Prasad---Aishwarya Rajesh, Vidhu, Surya Ganapathy, Madhuri, Pavel Navageethan, Avantika Vandanapu',
#  'S.S. Rajamouli---Prabhas, Rana Daggubati, Anushka Shetty, Tamannaah Bhatia, Sathyaraj, Nassar, Ramya Krishnan, Sudeep',
#  'B. V. Nandini Reddy---Samantha Ruth Prabhu, Lakshmi, Rajendraprasad, Naga Shourya, Rao Ramesh, Teja Sajja, Pragathi, Jagapathi Babu, Aishwarya, Urvashi',
#  'Louis C.K.---Louis C.K.',
#  'Alastair Fothergill---David Attenborough',
#  'Edward Cotterill---Rachael Stirling',
#  'Stan Lathan---Dave Chappelle',
#  'Walter C. Miller---Sam Kinison',
#  'S.S. Rajamouli---Prabhas, Rana Daggubati, Anushka Shetty, Tamannaah Bhatia, Sathyaraj, Ramya Krishnan, Nassar, Subbaraju',
#  'Ashwin Saravanan---Taapsee Pannu, Vinodhini, Parvathi T, Ramya Subramanian, Sanchana Natarajan, Anish Kuruvilla, David Solomon Raja',
#  'Jay Karas---Bill Burr']

# %% [markdown]
# As can be seen above, there are 12 director---cast pairs which have been repeated 3 or more times.
# So, if there is any record where director column is null, but the cast column is non-null and belongs to one of the casts above, then that null director will be replaced by the director value from above list

# %% [markdown]
# For example, if a record contains cast as 'Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil', and director is null, then that director will be Rajiv Chilaka. Because Rajiv Chilaka has done 3 or more movies with the exact same cast.

# %%
# converting the above column in to two different values in a dictionary
direcast = dict()
for i in found_directors:
    director,cast = i.split('---')
    direcast[director]=cast

# %%
direcast
# Out:
# {'Rajiv Chilaka': 'Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil',
#  'Rathindran R Prasad': 'Aishwarya Rajesh, Vidhu, Surya Ganapathy, Madhuri, Pavel Navageethan, Avantika Vandanapu',
#  'S.S. Rajamouli': 'Prabhas, Rana Daggubati, Anushka Shetty, Tamannaah Bhatia, Sathyaraj, Ramya Krishnan, Nassar, Subbaraju',
#  'B. V. Nandini Reddy': 'Samantha Ruth Prabhu, Lakshmi, Rajendraprasad, Naga Shourya, Rao Ramesh, Teja Sajja, Pragathi, Jagapathi Babu, Aishwarya, Urvashi',
#  'Louis C.K.': 'Louis C.K.',
#  'Alastair Fothergill': 'David Attenborough',
#  'Edward Cotterill': 'Rachael Stirling',
#  'Stan Lathan': 'Dave Chappelle',
#  'Walter C. Miller': 'Sam Kinison',
#  'Ashwin Saravanan': 'Taapsee Pannu, Vinodhini, Parvathi T, Ramya Subramanian, Sanchana Natarajan, Anish Kuruvilla, David Solomon Raja',
#  'Jay Karas': 'Bill Burr'}

# %% [markdown]
# The conversion to dictionary separates the values in to director name and cast. It is required because these two columns were combined just to see their joint frequency. Separating them and storing as a dictionary will allow for better lookup and cleaning as done in the next code snippet.

# %% [markdown]
# Below, the data records with null director and cast equal to the cast value of ith record in the direcast dictionary is taken and then assigned with the director value from the same ith record. It is achieved using .loc function in pandas.
# direcast.items())[i][1] : .items basically makes a list of tuples of the director,cast values. [i] gets the records in serial order and then [1] gets the cast, as the tuple is of the form (director, cast). Then if both conditions, director null and cast equal to cast in direcast are met, then the director value from direcast is used to fill the null value in director column of the data.
# The same procedure is followed for every director,cast pair in the direcast dictionary, as these are the only values which can be logically used to replace null director values.

# %%
for i in range(len(direcast)):
    data.loc[(data['director'].isna()) & (data['cast'] == list(direcast.items())[i][1]),'director'] = list(direcast.items())[i][0]

# %%
# checking again for the null values
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2616
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dcast           3107
# dtype: int64

# %% [markdown]
# Using the above logic, 18 null director values out of 2634 have been replaced. It is quite less as compared to the overall values, but there is no other logical way to move forward in this case.
# The remaining null values are assigned 'Not Given' value in the below code'

# %%
data.loc[data['director'].isna(),'director'] = 'Not Given'
# Assign Not Given to all other directors
# There is no other way to fill in null values, apart from actually searching for movie directors online and then manually filling them one by one

# %% [markdown]
# ### Cleaning null values in country column

# %% [markdown]
# For cleaning null values in country column, the logic is almost similar to the one used for cleaning null directors. The country can be estimated from the director and movie because they are related to each other. So, the below code uses director information, wherever available, to replace null country values.

# %%
# making a dictionary to store director and it's country as a pair
direc_cntry = dict(list(zip(data['director'],data['country'])))
direc_cntry
# Out:
# {'Kirsten Johnson': 'United States',
#  'Not Given': nan,
#  'Julien Leclercq': 'France, Belgium',
#  'Mike Flanagan': 'United States',
#  'Robert Cullen, José Luis Ucha': nan,
#  'Haile Gerima': 'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#  'Andy Devonshire': 'United Kingdom',
#  'Theodore Melfi': 'United States',
#  'Kongkiat Komesiri': nan,
#  'Christian Schwochow': 'Germany, Czech Republic',
#  'Bruno Garotti': 'Brazil',
#  'Pedro de Echave García, Pablo Azorín Williams': nan,
#  'Adam Salky': nan,
#  'Olivier Megaton': 'United States',
#  'K.S. Ravikumar': nan,
#  'Alex Woo, Stanley Moore': 'United States',
#  'S. Shankar': 'India',
#  'Rajiv Menon': nan,
#  'Dennis Dugan': 'United States',
#  'Scott Stewart': 'United States',
#  'Robert Luketic': 'United States',
#  'Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket Chaudhary': nan,
#  'Daniel Sandu': nan,
#  'Cédric Jimenez': nan,
#  'George Nolfi': 'China, Canada, United States',
#  'Rajiv Chilaka': nan,
#  'Steven Spielberg': 'United States, India',
#  'Jeannot Szwarc': 'United States',
#  'Joe Alves': 'United States',
#  'Joseph Sargent': 'United States',
#  'Tyler Greco': nan,
#  'Daniel Espinosa': 'South Africa, United States, Japan',
#  'Bunmi Ajakaiye': 'South Africa',
#  'Antoine Fuqua': 'United States',
#  'Toshiya Shinohara': 'Japan',
#  'Masahiko Murata': 'Japan',
#  'Hajime Kamegaki': 'Japan',
#  'Hirotsugu Kawasaki': 'Japan',
#  'Toshiyuki Tsuru': 'Japan',
#  'Tensai Okamura': 'Japan',
#  'David Yarovesky': nan,
#  'Hanns-Bruno Kammertöns, Vanessa Nöcker, Michael Wech': nan,
#  'David A. Vargas': nan,
#  'Kemi Adetiba': 'Nigeria',
#  'Ben Simms': 'United States',
#  'Prakash Satam': nan,
#  'Delhiprasad Deenadayalan': nan,
#  'Tomer Eshed': nan,
#  'Cedric Nicolas-Troyan': 'United States',
#  'JJC Skillz, Funke Akindele': 'Nigeria',
#  'Thomas Sieben': 'Germany',
#  'Marcus Clarke': nan,
#  'Alice Waddington': 'Spain, United States',
#  'Mona Achache, Patricia Tourancheau': 'France',
#  'Alexis Almström': nan,
#  'Raja Gosnell': 'United States',
#  'Stephen Kijak': 'United States',
#  'Chapman Way, Maclain Way': 'United States',
#  'Jason Hehir': nan,
#  'Yemi Amodu': nan,
#  'Lijo Jose Pellissery': 'India',
#  'David de Vos': 'United States',
#  'Luis Alfaro, Javier Gómez Santander': nan,
#  'Sara Colangelo': 'United States, Israel, United Kingdom, Canada',
#  'Stephen Herek': 'United States, Canada',
#  'Rahul Rawail': 'India',
#  'Jane Campion': 'New Zealand, Australia, France, United States',
#  'Nagesh Kukunoor': 'India',
#  'Luke Holland': 'United Kingdom, United States',
#  'Shanker Raman': 'India',
#  'JP Habac': 'Philippines',
#  'Vidhu Vinod Chopra': 'India',
#  'Mark Rosman': 'United States, Canada',
#  'Gilles Paquet-Brenner': 'France',
#  'Lasse Hallström': 'United States, India, United Arab Emirates',
#  'Scott Pleydell-Pearce': nan,
#  'Ridley Scott': 'United States, United Kingdom',
#  'Neill Blomkamp': 'South Africa, United States, New Zealand, Canada',
#  'Phillip Noyce': 'United States',
#  'Renny Harlin': 'China, Hong Kong, United States',
#  'Anthony Minghella': 'United States',
#  'Simon Wincer': 'United States, France, Mexico',
#  'Spike Lee': 'United States',
#  'Sebastián Schindel': 'Argentina',
#  'Steven C. Miller': 'Canada, United States',
#  'Richard LaGravenese': 'United States',
#  'Martin Campbell': 'United States, Germany, Mexico',
#  'Reginald Hudlin': 'United States',
#  'George Jackson, Doug McHenry': 'United States',
#  'Eric Meza': 'United States',
#  'Gerhard Mostert': nan,
#  'Michael Martin': 'United States',
#  'Michael Rymer': 'United States',
#  'Andrew Lau Wai-keung, Alan Mak': 'China, Hong Kong',
#  'Brett Weiner': 'United States',
#  'Jim Henson': 'United Kingdom, United States',
#  'Gary Winick': 'United States',
#  'Danishka Esterhazy': 'Canada',
#  'Troy Byer': 'United States',
#  'Pang Ho-cheung': 'Hong Kong',
#  'Tim Burton': 'United States, United Kingdom',
#  'David Zucker': 'United States',
#  'Kinka Usher': 'United States',
#  'Sergio Leone': 'Italy, United States',
#  "Matthew O'Callaghan, Todd Wilderman": 'United States, Canada',
#  'Bobby Farrelly, Peter Farrelly': 'United States',
#  'Wolfgang Petersen': 'United States, Germany',
#  'Peter Spirer': 'United States',
#  'Michael Carney': 'United States',
#  'Richard Linklater': 'United States, Germany',
#  'Amy Rice': 'United States',
#  'Randal Kleiser': 'United States',
#  'Michael Ritchie': 'United States',
#  'J. Lee Thompson': 'United Kingdom, United States',
#  'Evan Goldberg, Seth Rogen': 'United States',
#  'Tom Shadyac': 'United States',
#  'Peter Segal': 'United States',
#  'Malcolm D. Lee': 'United States',
#  'Ramzy Bedia, Éric Judor': 'France',
#  'Sharan Koppisetty': 'India',
#  'Taylor Sheridan': 'United Kingdom, Canada, United States',
#  'Sachin Yardi': 'India',
#  'Saurabh Kabra': 'India',
#  'Mark Waters': 'United States',
#  'Partho Mitra': 'India',
#  'Santram Varma': 'India',
#  'Anil V. Kumar, Anurag Basu': 'India',
#  'Sangeeth Sivan': 'India',
#  'Umesh Ghadge': 'India',
#  'David Dhawan': 'India',
#  'Dibakar Banerjee': 'India',
#  'Apoorva Lakhia': 'India',
#  'Milan Luthria': 'India',
#  'Pawan Kripalani': 'India',
#  'Bhushan Patel': 'India',
#  'Magnus Martens': nan,
#  'Raj Nidimoru, Krishna D.K.': 'India',
#  'Joshua Rofé': nan,
#  'Brad Anderson': 'United States',
#  'Mauricio Dias, Tatiana Villela': nan,
#  'Angel Kristi Williams': 'United States',
#  'Roger Donaldson': 'United States',
#  'Christopher Alender': 'United States',
#  'Rush Sturges': nan,
#  'David Oyelowo': 'United States',
#  'Mark Lo': 'United Kingdom',
#  'Crystal Moselle': nan,
#  'Rathindran R Prasad': nan,
#  'Han Kwang Il': nan,
#  'Karim El Shenawy': nan,
#  'Yin Chen-hao': nan,
#  'Brian Andrew Mendoza': 'United States',
#  'Dave Needham': nan,
#  'Veronica Velasco': nan,
#  'Drake Doremus': 'United States, Indonesia',
#  'Miguel Alexandre': nan,
#  'Mani Ratnam': 'India',
#  'Michael Harte': nan,
#  'Tosin Igho': nan,
#  'Alice Filippi': nan,
#  'Paakhi Tyrewala': 'India, Nepal',
#  'Laura Brownson': 'United States',
#  'Steve Brill': 'United States',
#  'Moses Inwang': 'Nigeria',
#  'Ferdinando Cito Filomarino': 'Italy, Brazil, Greece',
#  'Juan Carlos Medina': 'France',
#  'Inma Torrente': 'Spain',
#  'Julián Gaviria': 'Colombia',
#  'Steven Yamamoto': 'United States, Japan',
#  'Charles Uwagbai': 'Nigeria',
#  'Julián Hernández': 'Mexico',
#  'Sam Hobkinson': 'United Kingdom',
#  'Vince Marcello': 'United Kingdom, United States',
#  'Jonathan Teplitzky': 'Switzerland, United Kingdom, Australia',
#  'Sakon Tiacharoen': nan,
#  'Floyd Russ': 'United States',
#  'Dustin Hoffman': 'United Kingdom',
#  'Adze Ugah': 'South Africa, Nigeria',
#  'Hideaki Takizawa': nan,
#  'Quoc Bao Tran': 'United States',
#  'Bejoy Nambiar, Priyadarshan, Karthik Narain, Vasanth Sai, Karthik Subbaraj, Arvind Swamy, Rathindran R Prasad, Sarjun, Gautham Vasudev Menon': 'India',
#  'Kayode Kasum': 'Nigeria',
#  'Just Philippot': 'France',
#  'Kirk DeMicco, Brandon Jeffords': 'Canada, United States',
#  'Rohit Shetty': 'India',
#  'Cavi Borges, Luciano Vidigal': 'Brazil',
#  'Alejandro Doria': 'Argentina',
#  'Laura Fairrie': 'United Kingdom',
#  'Marcelo Piñeyro': 'Argentina, Spain',
#  'Izu Ojukwu': 'Nigeria',
#  'Peter Winther': 'United States',
#  'Susan Lacy': 'United States',
#  'Billy Corben': 'United States',
#  'James Mangold': 'United States',
#  'Chineze Anyaene': 'United States, Nigeria',
#  'Hsu Fu-chun': nan,
#  'Kristine Stolakis': 'United States',
#  'Eva Müller, Michael Schmitt': nan,
#  'Brian Levant': 'United States',
#  'Rod Daniel': 'United States',
#  'Robert Zemeckis': 'United States',
#  'Todor Chapkanov': 'Bulgaria, United States',
#  'Phil Lord, Christopher Miller': 'United States, Canada',
#  'John Hughes': 'United States',
#  'Justin Baldoni': 'United States',
#  'Joe Roth': 'United States',
#  'Mark Helfrich': 'United States, Canada',
#  'Mag Hsu, Hsu Chih-yen': nan,
#  'Christopher Nolan': 'United States, United Kingdom',
#  'Paul Thomas Anderson': 'United Kingdom',
#  'Nick Castle': 'United States',
#  'Howard Zieff': 'United States',
#  'David Feiss': 'United States, Canada',
#  'David Gordon Green': 'United States',
#  'Jorge Blanco': 'Spain, United Kingdom, United States',
#  'Zara Hayes': 'United Kingdom, United States',
#  'Gary Ross': 'United States',
#  'Clint Eastwood': 'United States',
#  'Trey Parker': 'United States, Germany',
#  'Kelly Fremon Craig': 'United States, China',
#  'Tom Elkins': 'United States',
#  'Tony Scott': 'United States, United Kingdom',
#  'Brad Furman': 'United States',
#  'Sylvain White': 'United States, France',
#  'Irwin Winkler': 'United States',
#  'Garry Marshall': 'United States',
#  'Kenneth Gyang': 'Nigeria',
#  'Jaume Balagueró': nan,
#  'Najwa Najjar': nan,
#  'Selçuk Metin': nan,
#  'Keishi Otomo': nan,
#  'David Charhon': nan,
#  'Michelle Bello': 'Nigeria',
#  'Steven Tsuchida': nan,
#  'Daniel Markowicz': 'Poland',
#  'Louie Schwartzberg': 'United States',
#  'Glen Winter': 'United States',
#  'Ram Gopal Varma': 'India',
#  'David Benullo': nan,
#  'Laxman Utekar': 'India',
#  'Royale Watkins, Rich Schlansker': nan,
#  'Yuval Adler': 'France, Israel, Germany, United States, United Kingdom',
#  'Quentin Tarantino': 'United States',
#  'Clay Glen': 'Australia',
#  'Muzi Mthembu': nan,
#  'Marcos Bucay': 'Mexico, Argentina',
#  'Peter Thorwarth': nan,
#  'Kim Seong-hun': 'South Korea, United States',
#  'Augustine Frizzell': 'United Kingdom',
#  'Sidheswar Shukla': nan,
#  'Binayak Das': nan,
#  'Arpan Sarkar, Shyamal Chaulia': nan,
#  'Rajiv Chilaka, Owll Mina': nan,
#  'Ainsley Gardiner, Briar Grace-Smith': 'New Zealand',
#  'Mahmoud Karim': 'Egypt',
#  'Kyohei Ishiguro': nan,
#  'Seyi Babatope': 'Nigeria',
#  'Johane Matte, Andrew L. Schmidt, Francisco Ruiz Velasco': nan,
#  'Morgan Ingari': 'United States',
#  'Abdulaziz Alshlahei': 'Saudi Arabia',
#  'Edward Drake': 'United States',
#  'Kathryn Fasegha': nan,
#  'Sita Likitvanichkul, Jetarin Ratanaserikiat, Apirak Samudkitpaisan, Thanabodee Uawithya, Adirek Wattaleela': 'Thailand',
#  'Leigh Janiak': nan,
#  'Luis Estrada': 'Mexico',
#  'Garrett Bradley': nan,
#  'Sofia Coppola': 'United States',
#  'Colin Trevorrow': 'United States',
#  'Bill Condon': 'United States',
#  'David Slade': 'United States',
#  'Chris Weitz': 'United States',
#  'Catherine Hardwicke': 'United States',
#  'Hadrah Daeng Ratu': 'Indonesia',
#  'Tommy Chong': nan,
#  'Fred Ouro Preto': nan,
#  'Mayye Zayed': 'Egypt, Denmark, Germany',
#  'Alessandra de Rossi': nan,
#  'Ash Brannon, Chris Buck': 'United States, Canada',
#  'Alaa Eddine Aljem': nan,
#  'Tom Donahue': 'United States',
#  'Roberto De Feo, Paolo Strippoli': 'Italy',
#  'Navot Papushado': nan,
#  'Manuel Alcalá': nan,
#  'Ricardo Trogi': nan,
#  'Semi Chellas': 'United States, Canada',
#  'Akay Mason, Abosi Ogba': nan,
#  'Viridiana Lieberman': 'United States',
#  'Nima Nourizadeh': 'United States, Switzerland',
#  'Daniel Růžička': nan,
#  'Juraj Šajmovič': nan,
#  'Femi D. Ogunsanwo': nan,
#  'Douglas Attal': nan,
#  'Kim Joo-hyung': 'South Korea',
#  'Avi Federgreen': nan,
#  'Jericca Cleland, Kevin Munroe': 'Hong Kong, Canada, United States',
#  'Ahmed Siddiqui': 'Kuwait, United States',
#  'Hallie Meyers-Shyer': 'United States',
#  'Scott Speer': 'United States',
#  'Barry Levinson': 'United States',
#  'Tolulope Itegboje': nan,
#  'Camille Delamarre': 'France, Canada, United States, Spain',
#  'Pascal Atuma': nan,
#  'Oleg Trofim': nan,
#  'Mahmood Ali-Balogun': 'Nigeria',
#  'Jan Holoubek': 'Poland',
#  'Anurin Nwunembom, Musing Derrick': nan,
#  'Christine Luby': 'Australia',
#  'Udoka Oyeka': nan,
#  'Yeo Siew Hua': 'France, Netherlands, Singapore',
#  'Hardik Mehta': 'India',
#  'Rajveer Singh Maan, Harpeet Singh': 'India',
#  'Youssef Chahine': 'France, Egypt',
#  'Saw Teong Hin, Nik Amir Mustapha, M.S. Prem Nath': 'Malaysia',
#  'Rano Karno': 'Indonesia',
#  'Pramod Pawar': 'India',
#  'Naresh Saigal': 'India',
#  'Vinil Mathew': 'India',
#  'Neri Parenti': nan,
#  'Ramsey Nouah': 'Nigeria',
#  'Bong Joon Ho': 'South Korea, United States',
#  'Kim Tae-hyung': 'South Korea',
#  'Michael Spierig, Peter Spierig': 'Australia, United States',
#  'Ernie Barbarash': 'United States',
#  'Matt Ogens': nan,
#  'Jay Roach': 'United States',
#  'McG': 'United States, Germany, United Kingdom, Italy',
#  'Frank Marshall': 'United States',
#  'Victor Vu': 'Vietnam',
#  'Chow Hin Yeung Roy': nan,
#  'Joel Hopkins': 'United Kingdom, Belgium',
#  'John Stevenson, Mark Osborne': 'United States, China',
#  'Jennifer Yuh Nelson': 'United States, China',
#  'Greg Berlanti': 'United States',
#  'Garth Davis': 'United Kingdom, Australia, United States',
#  'Malik Nejer': 'Saudi Arabia',
#  'Rob Marshall': 'United States, United Kingdom',
#  'Martin Brest': 'United States',
#  'Shuko Murase': nan,
#  'Paul W.S. Anderson': 'Germany, France, United States, Canada, United Kingdom',
#  'Ivan Reitman': 'United States',
#  'Joel Gallen': 'United States',
#  'Claire McCarthy': 'United Kingdom, United States',
#  'Mary Lambert': nan,
#  'Sidharta Tata, Aco Tenriyagelli, Dian Sastrowardoyo, Ifa Isfansyah, Jason Iskandar': nan,
#  'Trevor Nunn': 'United Kingdom',
#  'Gabriele Muccino': 'United States',
#  'Jim Field Smith': 'United States',
#  'Chris Koch': 'United States',
#  'J.J. Abrams': 'United States, Germany',
#  'Rob Minkoff': 'United States, China',
#  'Lynn Shelton': 'United States',
#  'Adam McKay': 'United States',
#  'Anton Corbijn': 'United States, United Kingdom',
#  'Robin Bissell': 'United States',
#  'David Fincher': 'United States',
#  'John G. Avildsen': 'United States',
#  'Alan Parker': 'United Kingdom, Germany, Spain, United States',
#  'Walter Hill': 'France, Canada, United States',
#  'Stephen Frears': 'United Kingdom, United States, France',
#  'Bryan Bertino': 'United States, Canada',
#  'Phil Alden Robinson': 'United States, Germany, Canada',
#  'Florian Henckel von Donnersmarck': 'Germany',
#  'Len Wiseman': 'United States, United Kingdom, Germany, Hungary',
#  'Måns Mårlind, Björn Stein': 'United States',
#  'Patrick Tatopoulos': 'United States, New Zealand',
#  'Robert O. Peters': nan,
#  'Vincent Ward': 'United States, New Zealand',
#  'Gregory Nava': 'United States',
#  'Mary Harron': 'United States, Canada',
#  'Matt Thompson': 'United States',
#  'Jameel Buari': nan,
#  'Shen Leping': nan,
#  'Matt Aselton': 'United States',
#  'Jose Javier Reyes': nan,
#  'Jakub Piątek': nan,
#  'John Dower': 'United Kingdom',
#  'B. T Thomas': nan,
#  'Andrew Dominik': 'United States',
#  'Nibal Arakji': nan,
#  'Sofie Šustková': nan,
#  'Anissa Bonnefont': 'France',
#  'Bahij Hojeij': 'Lebanon',
#  'Jonathan Hensleigh': 'United States',
#  'Srijit Mukherji, Vasan Bala, Abhishek Chaubey': nan,
#  'Justin P. Lange': 'United States',
#  'Kimmy Gatewood': nan,
#  'Tània Balló': nan,
#  'Manolo Caro': nan,
#  'Anurin Nwunembom': nan,
#  'Jayme Monjardim': 'Brazil',
#  'Kingsley Ogoro': nan,
#  'Cristina Jacob': 'Romania',
#  'Fernando Moro': 'Spain',
#  'Ivan Andrew Payawal': nan,
#  'Yoshiyuki Tomino, Yoshikazu Yasuhiko': nan,
#  'Yoshiyuki Tomino': nan,
#  'Rob Seidenglanz': 'United States',
#  'Simon Frederick': 'United Kingdom',
#  'Michihito Fujii': nan,
#  'Paul Weitz': 'United States',
#  'Karthik Subbaraj': 'India',
#  'Lucky Kuswandi': 'Indonesia',
#  'Soudade Kaadan': 'Syria, France, Lebanon, Qatar',
#  'Antoinette Jadaone': 'Philippines',
#  'Marie Clements': 'Canada',
#  'David O. Russell': 'United States',
#  'Achille Brice': nan,
#  'Max Jabs': 'Germany',
#  'Sarawut Wichiensarn': nan,
#  'Ricardo de Montreuil': 'United States',
#  'Peter Chelsom': 'United States',
#  'Michael Lockshin': nan,
#  'Francine Parker': 'United States',
#  'Daniel Schechter': 'United States',
#  'Mike Gunther': 'United States',
#  'David Zeiger': 'United States',
#  'Michael Simon': 'United States',
#  'Jerry Rothwell': 'Canada, United Kingdom, Netherlands',
#  'Joe Berlinger, Bruce Sinofsky': 'United States',
#  'Ian Cheney, Sharon Shattuck': 'United States',
#  'Bradley Parker': 'United States',
#  'Prabhakaran': 'India',
#  'Manjari Makijany': 'United States, India',
#  'Jay Oliva': 'Philippines, Singapore, Indonesia',
#  'Chris Appelhans': 'China, United States, Canada',
#  'Michael Tiddes': 'United States',
#  'Lara Saba': 'Lebanon, United Arab Emirates',
#  'Bao Nhan, Namcito': 'Vietnam',
#  'Mark Raso': 'Canada, United States',
#  'Tariq Alkazim': 'United Arab Emirates',
#  'Yulene Olaizola': 'Mexico, France, Colombia',
#  'Matthew Heineman': 'United Kingdom, United States',
#  'Robert Peters': 'Nigeria',
#  'Jonathan Clay': 'United States',
#  'Ally Pankiw': 'United Kingdom',
#  'George Ford': nan,
#  'Lee Kae-byeok': 'South Korea',
#  'Jayan Moodley': 'South Africa',
#  'Daniel Benmayor': 'United States',
#  'Alex Díaz': 'Mexico',
#  'Helena Bergström': 'Sweden',
#  'Alejandro De Grazia, Juan Stadler': 'Argentina',
#  'Myriam Fares': 'United Arab Emirates',
#  'Chiaki Kon': nan,
#  'Rae Red': 'Philippines',
#  'Lance Hool': 'United States',
#  'Nicole Conn': 'United States',
#  'Les Mayfield': 'United States',
#  'Ellen Seidler, Megan Siler': 'United States',
#  'Roger Christian': 'United States',
#  'Peter Galison': nan,
#  'Lance Young': 'Canada, United States',
#  'Leandro Neri': 'Brazil',
#  'Thom Fitzgerald': 'United States, Canada',
#  'Don Michael Paul': 'United States, South Africa',
#  'Andrzej Bartkowiak': 'United States',
#  'Harold Becker': 'United States',
#  'Andrew Jenks': 'United States',
#  'Ric Roman Waugh': 'United States',
#  'Rob Reiner': 'United States',
#  'Andy Tennant': 'United States',
#  'Tade Ogidan': 'Nigeria',
#  'Scott Spiegel': 'United States',
#  'Jessie Nelson': 'United States',
#  'Theodore Witcher': 'United States',
#  'Aurora Guerrero': 'United States',
#  'Michael Jai White': 'United States',
#  'James McTeigue': 'United States, United Kingdom, Germany',
#  'Takuya Igarashi': 'Japan',
#  'Michelle MacLaren': 'Canada, United States',
#  'Hidenori Inoue': nan,
#  'Todd Phillips': 'United States, Cambodia, Romania',
#  'Steve Ball': 'United States',
#  'Dominic Sena': 'United States',
#  'Alan Alda': 'United States',
#  'Mika Kaurismäki': nan,
#  'Sydney Pollack': 'United Kingdom, France, Germany, United States',
#  'Lorene Scafaria': 'United States',
#  'Barbra Streisand': 'United States',
#  'Michael Winterbottom': 'United Kingdom',
#  'Emma Tammi': 'United States',
#  'Peter Hutchings': 'United States',
#  'George Ratliff': 'United States',
#  'Bo Burnham': 'United States',
#  'Ekene Som Mekwunye': 'Nigeria',
#  'David Frankel': 'United States',
#  'Kevin Johnson': nan,
#  'José Larraza, Marc Pons': nan,
#  'Gary Sing': nan,
#  'Julio Quintana': 'United States',
#  'Paween Purijitpanya': 'Thailand',
#  'Pablo Faro': 'Argentina',
#  'Letizia Lamartire': 'Italy',
#  'Ray Jiang': nan,
#  'Daniel Vernon': nan,
#  'Steve Gukas': 'Nigeria',
#  'Tim Johnson': 'United States',
#  'Vishwesh Krishnamoorthy': 'India',
#  'Zack Snyder': 'United States, Australia',
#  'Uduak-Obong Patrick': nan,
#  'Mohamed Diab': 'Egypt, France',
#  'Amr Salama': 'Egypt',
#  'Christopher Amos': 'Australia',
#  'Robert Rodriguez': 'United States',
#  'David Ayer': 'United States',
#  'Eshom Nelms, Ian Nelms': 'United States',
#  'James Moll': 'United States',
#  'James Redford': 'United States',
#  'Kaashvie Nair': 'India',
#  'J.D. Dillard': 'United States',
#  'Nikhil Pherwani': 'India',
#  'Mae Czarina Cruz': 'Philippines',
#  'Praveen Kandregula': 'India',
#  'Cecilia Verheyden': 'Belgium, Netherlands',
#  'Daniel Minahan': 'United States',
#  'Donovan Marsh': 'South Africa',
#  'Brent Dawes': 'Mauritius',
#  'Leli Maki': 'Canada, South Africa',
#  'Uzodinma Okpechi': nan,
#  'Daniel Prochaska': 'Austria',
#  'Joe Wright': 'United States',
#  'Matthew Vaughn': 'United Kingdom, United States',
#  'Aditya Kripalani': 'India',
#  'Adriano Rudiman': nan,
#  'David Pablos': 'Mexico, France',
#  'Alexandre Aja': 'United States, Canada',
#  'Cai Cong': nan,
#  'Samuel Olatunji': nan,
#  'Ramon Térmens': 'Spain',
#  'Svetlana Cvetko': 'United States',
#  'Martin Prakkat': 'India',
#  'Baran bo Odar': 'Germany',
#  'Zhang Chong': 'China',
#  'Yılmaz Erdoğan': 'Turkey',
#  'Shantrelle P. Lewis': 'United States',
#  'Ivan Ayr': 'India',
#  'Anthony Mandler': 'United States',
#  'Vijay Roche': 'India',
#  "Stanley Menino D'Costa": 'India',
#  'Jennifer Brea': 'United Kingdom, United States',
#  'Julia von Heinz': 'Germany, France',
#  'Niels Arden Oplev': 'United States',
#  'Don Argott, Sheena M. Joyce': 'United States',
#  'Joshua Zeman': 'United States',
#  'Duncan Skiles': 'United States',
#  'Sean McNamara': 'United States',
#  'Vondie Curtis-Hall': 'United States',
#  'Robert Radler': 'United States',
#  'Roel Reiné': nan,
#  'Dean Parisot': 'United States',
#  'Paul Greengrass': 'Norway, Iceland, United States',
#  'Justin Kelly': 'United States',
#  'Eric Darnell, Tom McGrath, Conrad Vernon': 'United States',
#  'Suhas Kadav': 'India',
#  'Jeff Wadlow': 'United States',
#  'Charles Martin': 'China',
#  'Stella Corradi': 'United Kingdom',
#  'Roland Emmerich': 'United States, South Africa',
#  'Kevin Macdonald': 'United States, United Kingdom, France',
#  'Ann Deborah Fishman': 'United States',
#  'Chris Gorak': 'United States, Russia',
#  'Peter Jackson': 'New Zealand, United States',
#  'Roger Kumble': 'Germany, United States, Canada',
#  'Jonathan Lynn': 'United States',
#  'Courtney Hunt': 'United States',
#  'Pierre Greco, Nancy Florence Savard': 'Canada',
#  'Andrew Davis': 'France, United States',
#  'Kevin Smith': 'United States',
#  'Chaitanya Tamhane': 'India',
#  'Oriol Paulo': 'Spain',
#  'Mike Rianda, Jeff Rowe': nan,
#  'Johannes Roberts': 'United Kingdom, United States, Dominican Republic',
#  'Robert Pulcini, Shari Springer Berman': nan,
#  'Pedro Antonio': 'Brazil',
#  'John Wells': 'United States',
#  'Jonathan Liebesman': 'United States',
#  'Maria Pulera': 'Spain',
#  'Santhosh Viswanath': 'India',
#  'Seema Pahwa': 'India',
#  'Ozan Açıktan': 'Turkey',
#  'Meltem Bozoflu': 'Turkey, South Korea',
#  'Hakan Algül': 'Turkey',
#  'Selçuk Aydemir, Birkan Pusa': 'Turkey',
#  'Selçuk Aydemir': 'Turkey',
#  'Ömer Faruk Sorak': 'Turkey',
#  'Şenol Sönmez': 'Turkey',
#  'Alexis Morante': 'Spain',
#  'Burak Aksak': 'Turkey',
#  'Kıvanç Baruönü': 'Turkey',
#  'Rindala Kodeih': nan,
#  'Kongkiat Khomsiri': 'Thailand',
#  'Bedran Güzel': 'Turkey',
#  'Marwan Nabil': 'Egypt',
#  'MIKIKO, Daito Manabe': nan,
#  'Yılmaz Erdoğan, Ömer Faruk Sorak': 'Turkey',
#  'Takashi Shimizu': 'Japan',
#  'Alastair Fothergill': 'United Kingdom, United States, Spain, Germany, Greece, Canada',
#  'Joe Penna': 'Germany, United States',
#  'Ahishor Solomon': 'India',
#  'Curtis Graham': 'Canada, Nigeria, United States',
#  'Gerardo Gatica': 'Mexico',
#  'Akshay Sanjeev Chavan, Sumit Das': nan,
#  'John Madden': 'France, United States, United Kingdom, Canada',
#  'Edward James Olmos': 'United States',
#  'Abhinay Deo': 'India',
#  'Kiran Rao': 'India',
#  'Abbas Tyrewala': 'India',
#  'Ashutosh Gowariker': 'India',
#  'Satyajit Bhatkal': 'India',
#  'Anusha Rizvi, Mahmood Farooqui': 'India',
#  'Aamir Khan': 'India',
#  'Shashank Khaitan, Raj Mehta, Neeraj Ghaywan, Kayoze Irani': 'India',
#  'Ryan Crego': 'United States',
#  'Cassi Simonds': 'United States',
#  'Guillermo del Toro': 'United States',
#  'Tony Abulu': 'United States',
#  'Stefan Westerwelle': 'Germany',
#  'Ron Howard': 'United States',
#  'Justin Benson, Aaron Moorhead': 'United States',
#  'Niki Caro': 'Czech Republic, United Kingdom, United States',
#  'Mark Dennis, Ben Foster': 'United States',
#  'Taranveer Singh': 'India',
#  'TT The Artist': 'United States',
#  'Keiichi Sato, Yasushi Kawamura': 'Japan',
#  'Glenn Weiss': 'United States',
#  'Michael Civille': 'United States',
#  'Ryuichi Hiroki': 'Japan',
#  'One9': 'United States',
#  'Luis Valdez': 'United States',
#  'Cheng Wei-hao': 'China, Taiwan',
#  'Pass Patthanakumjon': 'Thailand',
#  'Buchi Babu Sana': 'India',
#  'Fredrick Munk': 'United States',
#  'Moyoung Jin, Caroline Sá, Deepti Kakkar, Fahad Mustafa, Hikaru Toda, Chico Pereira, Elaine McMillion Sheldon': 'United States, Brazil, Japan, Spain, India',
#  'Zhao Ji': 'China',
#  'Jamie Babbit': 'United States',
#  'Park Hoon-jung': 'South Korea',
#  'Dare Olaitan': 'Nigeria',
#  'Ben Falcone': 'United States',
#  'Travon Free, Martin Desmond Roe': 'United States',
#  'Angga Dwimas Sasongko': 'Indonesia',
#  'Steve Rolston': nan,
#  'Shalini Kantayya': 'China, Germany, India, United States',
#  'Madonne Ashwin': 'India',
#  'Enah Johnscott': 'Cameroon',
#  'Braden R. Duemmler': 'United States',
#  'Cal Brunker': 'United States, Canada',
#  'Steve Pink': 'United States',
#  'Xiao Feng': 'China',
#  'Ricky Staub': 'United Kingdom, United States',
#  'Patrick Durham, Paul G. Volk': 'United States',
#  'BB Sasore': 'Nigeria',
#  'Naseef Yusuf Izuddin': 'India',
#  'Appie Boudellah, Aram van de Rest': 'Netherlands',
#  'Sylvie Verheyde': 'United Kingdom, France',
#  'Nick Moore': 'United States, United Kingdom, France',
#  'Alex Zamm': 'United States',
#  'Rajkumar Hirani': 'India',
#  'Rajesh Mapuskar': 'India',
#  'Lina Al Abed': 'Lebanon, Palestine, Denmark, Qatar',
#  'James Wan': 'Canada, United States, United Kingdom',
#  'David Hackl': 'United States, Canada',
#  'Takeshi Nozue': 'Japan, United States',
#  'Subhash Kapoor': 'India',
#  'Ringo Lam': 'China, Hong Kong',
#  'George Cukor': 'United States',
#  'Tony Giglio': 'United States',
#  'Shinji Aramaki, Masaru Matsumoto': 'United States, Japan',
#  'John Luessenhop': 'United States',
#  'Hanung Bramantyo, Pandu Adjisurya': 'Indonesia',
#  'Bashir El Deek': 'Egypt, Saudi Arabia',
#  'Roman Polański': 'United Kingdom, France, Poland, Germany, United States',
#  'Nelson McCormick': 'United States, Canada',
#  'Mic Rodgers': 'United States',
#  'Bejoy Nambiar': 'India',
#  'Shawn Rech': 'United States',
#  'Peyton Reed': 'United States',
#  'Julian Schnabel': 'Ireland, Switzerland, United Kingdom, France, United States',
#  'Adrián García Bogliano': 'United States, Mexico',
#  'Jose Gomez': 'United Kingdom',
#  'Jonathon Link': 'United States',
#  'Blair Simmons': 'United Kingdom',
#  'Justin Chadwick': 'United Kingdom, South Africa, France',
#  'John Hillcoat': 'United States',
#  'Nadine Ibrahim': 'Nigeria',
#  'Roman White': 'United States',
#  'Fermín Muguruza': nan,
#  'Mike Hodges': 'Ireland, United Kingdom, France, Germany',
#  'Eylem Kaftan': 'Turkey',
#  'Fernando Ayllón': 'Colombia',
#  'Umesh Bist': 'India',
#  'Massimiliano Camaiti': 'Italy',
#  'Aleksey Tsitsilin': 'Russia, United States',
#  'Ali Tabrizi': 'United States',
#  'Kagiso Lediga': 'South Africa',
#  'Jung-ah Im': 'South Korea',
#  'Takuma Sato': 'Japan',
#  'Brody Chu': 'Taiwan',
#  'Dimitri Logothetis': 'United States',
#  'Taketoshi Sado': nan,
#  'Li Weiran': 'China',
#  'Chinaza Onuzo': 'Nigeria',
#  'Anna Elizabeth James': 'United States',
#  'Vitor Brandt': 'Brazil',
#  'Troy Miller': 'United States',
#  "Liam O'Donnell": 'United States, Canada, Indonesia, United Kingdom, China, Singapore',
#  'Manny Rodriguez, Jay Lavender': 'United States',
#  'Farah Nabulsi': 'United Kingdom,',
#  'Walter Taylaur': 'Nigeria',
#  'Chris Smith': 'Canada, United States',
#  'Alain Brunard': 'Belgium',
#  'Tate Taylor': 'United States',
#  'Ladislaus Kiraly': 'Germany',
#  'Oliver Stone': 'United States',
#  'Hemambar Jasti': 'India',
#  'Taylor Morden': 'United States',
#  'Helena Coan': nan,
#  'Muharrem Gülmez': 'Turkey',
#  'Dolapo Adeleke': 'Kenya',
#  'Mahsun Kırmızıgül': 'Turkey, United States',
#  'Can Ulkay': 'Turkey',
#  'Luis Alejandro Pérez': nan,
#  'Ketche': 'Turkey',
#  'Erol Özlevi': 'Turkey',
#  'Miguel Arteta': 'United States',
#  'Tolga Örnek': 'Turkey',
#  'Pablo Agüero': 'Spain, Argentina',
#  'Mohammad Irfan Ramly': 'Indonesia',
#  'Kevin McManus, Matthew McManus': 'United States',
#  'Ange Basterga, Nicolas Lopez': 'France',
#  'Gitanjali Rao': 'India, United Kingdom, France, Qatar',
#  'Halitha Shameem': 'India',
#  'Carlos Moreno': 'Colombia',
#  'Maribel Sánchez-Maroto': 'Spain',
#  'Fajar Bustomi': 'Indonesia',
#  'Taylor Hackford': 'United States',
#  'Amy Poehler': 'United States',
#  'Jared Hess, Tyler Measom': 'United States',
#  'Mike Binder': 'United States, United Kingdom',
#  'Abir Sengupta': 'India',
#  'Sunny Lau': nan,
#  'Emmett Malloy': 'United States',
#  'Xavier Maingon, Marc-Antoine Hélard': nan,
#  'Milton Kremer': nan,
#  'Kevin Costner': 'United States, United Kingdom',
#  'Marco Petry': 'Germany',
#  'Andrew Duncan, Ken Cunningham': 'United States',
#  'Liam Lynch': 'United States',
#  'Jérémie Degruson, Ben Stassen': 'Belgium, France',
#  'Matt Ross': 'United States',
#  'Dani de la Orden': 'Spain',
#  'Pablo Larraín': 'Chile, Argentina, France, Spain, United States',
#  'John Erick Dowdle': 'United States',
#  'Jesse Peretz': 'United States',
#  'Ribhu Dasgupta': 'India',
#  'Rizki Balki': 'Indonesia',
#  'Shunsuke Kariyama': 'Japan',
#  'Jeferson De': nan,
#  'Barry Avrich': 'Canada',
#  'David Tryhorn, Ben Nicholas': 'United Kingdom',
#  'Tirumala Kishore': 'India',
#  'Huang Hsin-Yao': 'Taiwan',
#  'Saron Sakina': nan,
#  'J Blakeson': 'United Kingdom, United States',
#  'Khalid Rahman': 'India',
#  'Luis Ara': 'Brazil',
#  'Tharun Bhascker Dhaassyam, B. V. Nandini Reddy, Nag Ashwin, Sankalp Reddy': 'India',
#  'Prateek Vats': 'India',
#  'Alex Merkin': 'United States',
#  'Ian Cheney': 'United States',
#  'Vikram Bhatt': 'India',
#  'Dallas Jenkins': 'United States',
#  'Damián Romay': 'United States',
#  'Hamisha Daryani Ahuja': 'Nigeria',
#  'Hong Khaou': 'United Kingdom',
#  'Stan Lathan': 'United States',
#  'Mario Briongos': 'Spain',
#  'Vinay Bharadwaj': 'India',
#  'Michael Fimognari': 'United States',
#  'Eric D. Cabello Díaz': 'Mexico',
#  'Clara Martínez-Lázaro': 'Spain',
#  'Monty Tiwa': 'Indonesia',
#  'Ava DuVernay': 'United States',
#  'Alain Darborg': 'Sweden',
#  'Filip Zylber': 'Poland',
#  'Joe Berlinger': 'United States',
#  'Julien Royal': 'France',
#  'Brian Baugh': 'United States',
#  'Henri Wong': 'China',
#  'Maïa Sandoz': 'France',
#  'Mostofa Sarwar Farooki': 'Bangladesh',
#  'Joseph Hsu': 'Taiwan',
#  'Sam Levinson': 'United States',
#  'Jo Sung-hee': 'South Korea',
#  'Michèle Ohayon': 'United States',
#  'Rocco Ricciardulli': 'Italy',
#  'Guo Jingming': 'China',
#  'Jan Belcl': 'Poland',
#  'Esteban Crespo': 'Spain',
#  'Noé González': 'Mexico',
#  'Sarah Gavron': 'United Kingdom, France',
#  'Martin Scorsese': 'United States',
#  'Richard Arellano': 'Philippines',
#  'Jon Favreau': 'United States',
#  'Marco Pontecorvo': 'Portugal, United States',
#  'Gregory Plotkin': 'United States',
#  'Lluís Quílez': 'Spain',
#  'Jude Weng': 'United States',
#  'Simon Stone': 'Australia',
#  'Noviandra Santosa': 'Indonesia',
#  'Jeremy Grant': 'United States',
#  'Jeo Baby': 'India',
#  'Glendyn Ivin': 'Australia, United States',
#  'Okey Oku': 'Nigeria',
#  'Ifeanyi Ikpoenyi': nan,
#  'Chris Eneng Enaji': nan,
#  'Ángeles Reiné': 'Portugal, Spain',
#  'Paul Haggis': 'United States, Germany',
#  'Ramin Bahrani': 'India, United States',
#  'Nicol Paone': 'United States',
#  'Nick Rowland': 'United Kingdom, Ireland',
#  'RZA': 'United States',
#  'Cooper Karl': 'United States',
#  'Gary Fleder': 'United States',
#  'J.A. Bayona': 'Spain, Thailand, United States',
#  'Darren Lynn Bousman': 'United States',
#  'Lydia Dean Pilcher, Ginny Mohler': 'United States',
#  "Cris D'Amato": 'Brazil',
#  'Mikael Håfström': 'Hungary, United States',
#  'Eric Darnell, Simon J. Smith': 'United States',
#  'Byeon Hee-sun': 'United States, South Korea',
#  'Peter Facinelli': 'United States',
#  'Renuka Shahane': 'India',
#  'Ross Kauffman': 'United States',
#  'Sung Do-jun': 'South Korea',
#  'Hanung Bramantyo': 'Indonesia',
#  'Charles Gozali, Bagus Bramanti': 'Indonesia',
#  'James Toback': 'United States, France',
#  'Tiller Russell': 'United States',
#  "Francisco D'Eufemia": 'Argentina',
#  'Chris Rock': nan,
#  'Juliet May': 'United Kingdom',
#  'Stanley Nelson': 'United States',
#  'Olivier Nakache, Éric Toledano': 'France',
#  'Prakash Jha': 'India',
#  'Rohan Sippy': 'India',
#  'Ross Venokur': 'Canada, United States, Cayman Islands',
#  'Rohena Gera': 'India, France',
#  'Maite Ruiz De Austri': 'Spain',
#  'Jastis Arimba': 'Indonesia',
#  'Eric Summer, Éric Warin': 'France, Canada',
#  'Kornél Mundruczó': 'Canada, Hungary, United States',
#  'Alejandro Ruax, Ramiro Martínez': nan,
#  'Florent Bodin': 'France',
#  'Sohail Khan': 'India',
#  'Hallvard Bræin': 'Norway',
#  'Jeff Tremaine': 'United States',
#  'Christian Alvart': 'United States, Canada',
#  'Robert Townsend': 'United States',
#  'Jeff Deverett': 'United States',
#  'Ron Krauss': 'United States',
#  'Brian Robbins': 'United States',
#  'Jeff Stilson': 'United States',
#  'Sean Penn': 'United States',
#  'Mark McQueen': 'United Kingdom',
#  'Melanie Mayron': 'United States',
#  'Donald Petrie': 'United States',
#  'Tony Collingwood': 'Canada, United Kingdom, United States',
#  'Jennifer Beamish, Toby Trackman': 'United States',
#  'Jaume Collet-Serra': 'United Kingdom, Germany, France, United States',
#  'Kim Dong-kyu': 'South Korea',
#  'Shaz Bennett': 'United States',
#  'Samar Shaikh': 'India',
#  'Archie Hekagery': 'Indonesia',
#  'Sabrina Rochelle Kalangie': 'Indonesia',
#  'Cosima Spender': 'United Kingdom',
#  'Liao Shih-han': 'Taiwan',
#  'Arnon Manor, Timothy Ware-Hill': 'United States',
#  'Gore Verbinski': 'United States',
#  'Al Campbell, Alice Mathias': 'United States',
#  'Maïwenn': 'France, Algeria',
#  'Richard Weston': 'United States',
#  'Vikramaditya Motwane': 'India',
#  'Prime Cruz': 'Philippines',
#  'Andibachtiar Yusuf': 'Indonesia',
#  'Yandy Laurens': 'Indonesia',
#  'Cathy Garcia-Molina': 'Philippines',
#  'John Mitchell, Jeremy Kipp Walker': 'United States',
#  'George Clooney': 'United States, France, United Kingdom, Japan',
#  'Liu Kuang-hui': 'Taiwan',
#  'Kristian Mercado': 'United States',
#  'Daan Jansen, Stijn Verlinde': 'Netherlands',
#  'Jay Grace': 'United Kingdom',
#  'Paul Dugdale': 'United Kingdom',
#  'James Haslam': 'United States, United Kingdom',
#  'Muhammad Ali': 'Egypt',
#  'Thomas Toby Parkinson': 'United Kingdom',
#  'John Putch': 'United States',
#  'Sam Macaroni': 'United States',
#  'George C. Wolfe': 'United States, Australia',
#  'Yasmin Ahmad': 'Malaysia',
#  'Sudha Kongara, Vignesh Shivan, Gautham Vasudev Menon, Vetri Maaran': 'India',
#  'Juan Camilo Pinzon': 'Colombia',
#  'Lin Oeding': 'Canada',
#  'Naya Anindita': 'Indonesia',
#  'Alexx Media': 'United States',
#  'Farishad I. Latjuba': nan,
#  'Andrucha Waddington, Pedro Waddington': 'Brazil',
#  'Picky Talarico': nan,
#  'Jun Lana': 'Philippines',
#  'Brad Peyton': 'United States, Australia',
#  'Lee Daniels': 'United States',
#  'Tom Ford': 'United States',
#  'Ellena Wood, Jesse Vile': 'United Kingdom',
#  'Vir Das': 'India',
#  'Miranda de Pencier': 'Canada',
#  'Farhad Safinia': 'Ireland, France, Iceland, United States, Mexico, Belgium, United Kingdom, Hong Kong',
#  'Shaun Paul Piccinino': 'United States',
#  'Eddie Rosas': nan,
#  'Frank E. Abney III': 'United States',
#  'James D. Stern, Fernando Villena': 'United States',
#  'Ryan Murphy': 'United States',
#  'Girish Malik': 'India',
#  'Deepa Mehta': 'Canada, United States',
#  'Lai Chun-yu': nan,
#  'Theodore Boborol': 'Philippines',
#  'Sydney Sibilia': 'Italy',
#  'Josiah Ng': 'Singapore',
#  'Kirk Wise': 'United States',
#  'Beth Sleven, Allan Jacobsen, Kevin Wotton': 'United States',
#  'Jalil Lespert': 'France, Belgium',
#  'Su I-Hsuan, Chuang Shiang-an, Liu Yi': 'Taiwan',
#  'Clint Butler': 'Canada',
#  'Erik Kling, Kevin Peaty': 'United States',
#  'Detlev Buck': 'Germany',
#  'Amanda Raymond': 'United States',
#  'Jason Paul Laxamana': 'Philippines',
#  'Marc Fouchard': 'France, Belgium',
#  "Darragh O'Connell": nan,
#  'Roberto Santucci': 'Brazil',
#  'Dado C. Lumibao': 'Philippines',
#  'August Jakobsson': 'Iceland',
#  'Anna Wieczur-Bluszcz': 'Poland',
#  'Damien O’Connor': 'Ireland, Canada',
#  'Richard Laxton': 'United Kingdom',
#  'Gil Kenan': 'United States',
#  'Phil Burgers': 'United States',
#  'Pierre Morel': 'France, United Kingdom, United States',
#  'Brian Henson': 'United States, China, Canada',
#  'Derick Cabrido': 'Philippines',
#  'Marla M. Ancheta': 'Philippines',
#  'Jen McGowan': 'United States',
#  'Bernie Denk': 'United States',
#  'Brian Skiba': 'United States',
#  'Stanley Moore, Alex Woo': nan,
#  'Oliver Bokelberg': 'United States',
#  'Ángel Gómez Hernández': 'Spain',
#  'Ludovico Di Martino': 'Italy',
#  'Lee Chung-hyun': 'South Korea',
#  'Barry Gonzalez': 'Philippines',
#  'Brian Volk-Weiss': 'United States',
#  'Matthew Michael Carnahan': 'United States',
#  'Eric Bress': 'United Kingdom',
#  'Chris Columbus': 'Canada',
#  'V Vignarajan': 'India',
#  'Greg Rankin, TJ Sullivan': 'United States',
#  'Carlos Sorín': 'Argentina',
#  'Matt Eskandari': 'United States',
#  'Grant Singer': 'United States',
#  'Mohammad Adel': 'Egypt',
#  'Debbie Allen': 'United States',
#  'Victor Gatonye': 'Kenya',
#  'Stephen Chiodo': 'United States',
#  'Will McCormack, Michael Govier': 'United States',
#  'Monica Floyd': 'United States',
#  'Anurag Kashyap': 'India',
#  'Siddique': 'India',
#  'Danish Aslam': 'India',
#  'Vibhu Virender Puri': 'India',
#  'Mike Rohl': 'United States',
#  'Shyam Benegal': 'India',
#  'Takeshi Fukunaga': 'United States, Japan',
#  'Leslie Small': 'United States',
#  'Jeff Nichols': 'United States',
#  'Sabaah Folayan, Damon Davis': 'United States',
#  'Justin G. Dyck': 'Canada',
#  'Cody Cameron, Kris Pearn': 'United States',
#  'Michael Curtiz': 'United States',
#  'Avinash Walzade': 'India',
#  'David E. Talbert': 'United States',
#  'Renata Terra': 'Brazil',
#  'Edoardo Ponti': 'Italy',
#  'Mateo Gil': 'Spain',
#  'Paul Soriano': 'Philippines',
#  'Ryan Coogler': 'United States',
#  'Anurag Basu': 'India',
#  'Lucas Santa Ana': 'Argentina',
#  'Carla Barros': 'Brazil',
#  'Ulrike Kofler': 'Austria',
#  'Steven Bognar, Julia Reichert': 'United States',
#  ...}

# %%
# same as the director column, the country values from direc_cntry are used to fill in null country values
for i in range(len(direc_cntry)):
    data.loc[(data['country'].isna()) & (data['director'] == list(direc_cntry.items())[i][0]),'country'] = list(direc_cntry.items())[i][1]

# %%
# checking for the null values after cleaning
data.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director           0
# cast             825
# country          734
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dcast           3107
# dtype: int64

# %% [markdown]
# Based on the above logic, 97 out of 831 null records in country have been cleaned. The rest of the columns are replaced by 'Not Given' in the below code line

# %%
data.loc[data['country'].isna(),'country'] = 'Not Given'

# %% [markdown]
# ### Cleaning null values in date_added, rating and duration columns

# %% [markdown]
# Number of null values in date_added, rating and duration columns is very small as compared to total records, so no effort is done cleaning these values and the records containing null values for these columns are simply dropped

# %%
# dropping records
data.drop(data[data['date_added'].isna()].index,axis=0,inplace=True)

# %%
# dropping records
data.drop(data[data['rating'].isna()].index,axis=0,inplace=True)
data.drop(data[data['duration'].isna()].index,axis=0,inplace=True)

# %%
# description column will be not be needed for visualization as it contains explanatory text, so this column is also dropped
data.drop(['dcast','description'],axis=1,inplace=True)

# %%
# null values in cast column are also replaced with Not Given
data.loc[data['cast'].isna(),'cast'] = 'Not Given'

# %%
# final check for number of null values in every column
data.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# As seen above, all null values have been dealt with

# %% [markdown]
# ### Checking the validity or inconsistency if any in date_added and release_year

# %% [markdown]
# It can be simply understood that date_added column should not contain any date value that comes before release_year. Because how can a movie be added on Netflix before it has even been released. So, the below code checks these inconsistencies and then deal with them appropriately

# %%
# the date_added column is converted to datetime data type for further analysis using date functions
import datetime as dt
data['date_added_date'] = pd.to_datetime(data['date_added'])

# %%
# check if there are any added_dates that come before release_year
sum(data['date_added_date'].dt.year < data['release_year'])
# Out:
# 14

# %% [markdown]
# As it can be seen, there are 14 records where the show or movie was added to netflix before it was released. Below code shows those records

# %%
data.loc[(data['date_added_date'].dt.year < data['release_year']),['date_added_date','release_year']]
# Out:
#      date_added_date  release_year
# 1551      2020-12-14          2021
# 1696      2020-11-15          2021
# 2920      2020-02-13          2021
# 3168      2019-12-06          2020
# 3287      2019-11-13          2020
# 3369      2019-10-25          2020
# 3433      2019-10-11          2020
# 4844      2018-05-30          2019
# 4845      2018-05-29          2019
# 5394      2017-07-01          2018
# 5658      2016-12-23          2018
# 5677      2016-12-13          2017
# 7063      2018-10-26          2019
# 7112      2013-03-31          2016

# %% [markdown]
# So, for dealing with these records, it is reasonable to assume that there has been a mistake in filling out the release years for these movies. Because date_added is supposed to be something that comes from the datalog system of netflix and is not supposed to be wrong. So, it is reasonable to alter the release year according to data added column as done in below code

# %%
# release_year values are replaced with year values from their respective date_added values
data.loc[(data['date_added_date'].dt.year < data['release_year']),'release_year'] = data['date_added_date'].dt.year

# %%
# some of the records above are checked and it is confirmed that they have been accurately replaced
data.iloc[[1551,1696,2920,3168]]
# Out:
#      show_id     type          title   director  \
# 1551   s1552  TV Show          Hilda  Not Given
# 1696   s1697  TV Show   Polly Pocket  Not Given
# 2920   s2921  TV Show  Love Is Blind  Not Given
# 3168   s3169  TV Show   Fuller House  Not Given
#
#                                                    cast  \
# 1551  Bella Ramsey, Ameerah Falzon-Ojo, Oliver Nelso...
# 1696  Emily Tennant, Shannon Chan-Kent, Kazumi Evans...
# 2920                        Nick Lachey, Vanessa Lachey
# 3168  Candace Cameron Bure, Jodie Sweetin, Andrea Ba...
#
#                                     country         date_added  release_year  \
# 1551  United Kingdom, Canada, United States  December 14, 2020          2020
# 1696         Canada, United States, Ireland  November 15, 2020          2020
# 2920                          United States  February 13, 2020          2020
# 3168                          United States   December 6, 2019          2019
#
#      rating   duration                      listed_in date_added_date
# 1551  TV-Y7  2 Seasons                       Kids' TV      2020-12-14
# 1696   TV-Y  2 Seasons                       Kids' TV      2020-11-15
# 2920  TV-MA   1 Season  Reality TV, Romantic TV Shows      2020-02-13
# 3168  TV-PG  5 Seasons                    TV Comedies      2019-12-06

# %% [markdown]
# Netflix was launched in 1997. So if there is any record that contains an addition to Netflix before this year, is supposed to be wrong and shall be dealt with

# %%
# checking if there is any addition to Netflix before 1997
sum(data['date_added_date'].dt.year < 1997)
# turns out that there is None
# Out:
# 0

# %% [markdown]
# ### Taking an overview of values in some columns for any invalid or inconsistent values

# %% [markdown]
# Columns like rating, duration and type are checked for their unique values. This is done to spot any invalid or inconsistent values, in case it exists. Based on below results, there does not seem to be any problem

# %%
# checking unique values for rating column
data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# checking unique values for duration column
data['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
#        '140 min', '78 min', '7 Seasons', '64 min', '59 min', '139 min',
#        '69 min', '148 min', '189 min', '141 min', '130 min', '138 min',
#        '81 min', '132 min', '10 Seasons', '123 min', '65 min', '68 min',
#        '66 min', '62 min', '74 min', '131 min', '39 min', '46 min',
#        '38 min', '8 Seasons', '17 Seasons', '126 min', '155 min',
#        '159 min', '137 min', '12 min', '273 min', '36 min', '34 min',
#        '77 min', '60 min', '49 min', '58 min', '72 min', '204 min',
#        '212 min', '25 min', '73 min', '29 min', '47 min', '32 min',
#        '35 min', '71 min', '149 min', '33 min', '15 min', '54 min',
#        '224 min', '162 min', '37 min', '75 min', '79 min', '55 min',
#        '158 min', '164 min', '173 min', '181 min', '185 min', '21 min',
#        '24 min', '51 min', '151 min', '42 min', '22 min', '134 min',
#        '177 min', '13 Seasons', '52 min', '14 min', '53 min', '8 min',
#        '57 min', '28 min', '50 min', '9 min', '26 min', '45 min',
#        '171 min', '27 min', '44 min', '146 min', '20 min', '157 min',
#        '17 min', '203 min', '41 min', '30 min', '194 min', '15 Seasons',
#        '233 min', '237 min', '230 min', '195 min', '253 min', '152 min',
#        '190 min', '160 min', '208 min', '180 min', '144 min', '5 min',
#        '174 min', '170 min', '192 min', '209 min', '187 min', '172 min',
#        '16 min', '186 min', '11 min', '193 min', '176 min', '56 min',
#        '169 min', '40 min', '10 min', '3 min', '168 min', '312 min',
#        '153 min', '214 min', '31 min', '163 min', '19 min', '12 Seasons',
#        '179 min', '11 Seasons', '43 min', '200 min', '196 min', '167 min',
#        '178 min', '228 min', '18 min', '205 min', '201 min', '191 min'],
#       dtype=object)

# %%
# checking unique values for type column
data['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %% [markdown]
# ### Data Transformation of "listed_in" column for additional granularity

# %% [markdown]
# The listed_in column contains categories under which a particular movie or TV show is listed. In this column, various categories are just clubbed together using comma as a separator. It may be beneficial to have them separated out also, in case one wants to analyze each category separately.

# %%
# checking the maximum number of categories there are in any record for listed_in column
max(data['listed_in'].str.split(',').apply(lambda x: len(x)))
# Out:
# 3

# %%
# splitting the listed_in column and storing the values in three nee separate columns
data['listed_in1'] = data['listed_in'].str.split(',',expand = True)[0]
data['listed_in2'] = data['listed_in'].str.split(',',expand = True)[1]
data['listed_in3'] = data['listed_in'].str.split(',',expand = True)[2]
# three columns used because the maximum number of categories that will be there after split is 3
# if after split the categories < 3, then the remaining columns will be filled with null value

# %%
# final inspection of data by viewing a few rows
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water        Not Given
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans        Not Given
# 4      s5  TV Show           Kota Factory        Not Given
#
#                                                 cast          country  \
# 0                                          Not Given    United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...     South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  France, Belgium
# 3                                          Not Given        Not Given
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...            India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in date_added_date  \
# 0                                      Documentaries      2021-09-25
# 1    International TV Shows, TV Dramas, TV Mysteries      2021-09-24
# 2  Crime TV Shows, International TV Shows, TV Act...      2021-09-24
# 3                             Docuseries, Reality TV      2021-09-24
# 4  International TV Shows, Romantic TV Shows, TV ...      2021-09-24
#
#                listed_in1               listed_in2              listed_in3
# 0           Documentaries                     None                    None
# 1  International TV Shows                TV Dramas            TV Mysteries
# 2          Crime TV Shows   International TV Shows   TV Action & Adventure
# 3              Docuseries               Reality TV                    None
# 4  International TV Shows        Romantic TV Shows             TV Comedies

# %% [markdown]
# # Storing cleaned data in to a new CSV file

# %%
data.to_csv('Netflix_Data.csv',sep=',',header=True,index=False)

# %% [markdown]
# This is the end of data wrangling in Python. Now the further visualization and analysis is done using Tableau
